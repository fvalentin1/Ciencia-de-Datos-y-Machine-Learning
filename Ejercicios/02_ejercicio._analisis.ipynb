# %%
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
# Cargar los datos desde un archivo CSV
df = pd.read_csv('./datos/ventas_mensuales.csv')
df.head()
# Out:
#        Mes  Ventas
# 0    Enero   10000
# 1  Febrero   12000
# 2    Marzo   15000
# 3    Abril   13000
# 4     Mayo   14000

# %%
# Descripción de los datos
df.describe()
# Out:
#              Ventas
# count     12.000000
# mean   16416.666667
# std     3752.776750
# min    10000.000000
# 25%    13750.000000
# 50%    16500.000000
# 75%    19250.000000
# max    22000.000000

# %%
# Contar los valores nulos
df.isnull().sum()
# Out:
# Mes       0
# Ventas    0
# dtype: int64

# %%
# Graficar los datos
plt.figure(figsize=(10, 6))
plt.plot(df['Mes'], df['Ventas'], marker='o', color='b', linestyle='-', linewidth=2)
plt.title('Ventas mensuales')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.grid()
plt.show()

# %%
media_ventas = df['Ventas'].mean()
print(f'Media de ventas: {media_ventas:.2f}')
# Out:
# Media de ventas: 16416.67

# %%
# Mes con más ventas
mes_mas_ventas = df[df['Ventas'] == df['Ventas'].max()]['Mes'].values[0]
print(f'Mes con más ventas: {mes_mas_ventas}')
# Out:
# Mes con más ventas: Diciembre

# %%
# Gráfico de barra de las ventas mensuales
plt.figure(figsize=(10, 6))
plt.bar(df['Mes'], df['Ventas'], color='g')
plt.title('Ventas mensuales')
plt.xlabel('Mes')
plt.ylabel('Ventas')
plt.grid()
plt.show()
